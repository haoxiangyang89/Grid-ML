# %%
import pandas as pd
file = "./result.csv"
csv_result = pd.read_csv(file)

# %%
csv_result
# Out:
#                            case_name     dual_status     objective  \
# 0          pglib_opf_case10480_goc.m  FEASIBLE_POINT  2.314648e+06
# 1      pglib_opf_case1951_rte__api.m  FEASIBLE_POINT  2.410827e+06
# 2          pglib_opf_case24464_goc.m  FEASIBLE_POINT  2.629531e+06
# 3     pglib_opf_case24464_goc__api.m  FEASIBLE_POINT  2.472270e+06
# 4     pglib_opf_case24464_goc__sad.m  FEASIBLE_POINT  2.653958e+06
# 5      pglib_opf_case2868_rte__api.m  FEASIBLE_POINT  2.294582e+06
# 6       pglib_opf_case39_epri__sad.m  FEASIBLE_POINT  1.483405e+05
# 7      pglib_opf_case4020_goc__api.m  FEASIBLE_POINT  1.297899e+06
# 8      pglib_opf_case4917_goc__sad.m  FEASIBLE_POINT  1.389049e+06
# 9       pglib_opf_case500_goc__api.m  FEASIBLE_POINT  6.924073e+05
# 10  pglib_opf_case8387_pegase__sad.m  FEASIBLE_POINT  2.803852e+06
# 11     pglib_opf_case9591_goc__api.m  FEASIBLE_POINT  1.425904e+06
#
#     objective_lb   primal_status   solve_time termination_status
# ...
